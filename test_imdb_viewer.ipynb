# %%
from pathlib import Path
import pandas as pd
pd.set_option("display.max_colwidth", 72)
csv_path = Path("test_imdb.csv")
df = pd.read_csv(csv_path, encoding="utf-8-sig")
df.tail(10)

# %%
df.isna().sum()

# %%
df[["song_title", "album", "year", "film_imdb_id", "lyricist_imdb_ids", "composer_imdb_ids", "singer_imdb_ids", "picturized_on_imdb_ids"]].head(20)
